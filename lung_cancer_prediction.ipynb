# %% [markdown]
# <a href="https://colab.research.google.com/github/nithishkumar02272000/lung_cancer_prediction/blob/main/lung_cancer_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets
# !pip pandas
# Out:
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatasets) (4.65.0)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (from opendatasets) (1.5.16)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from opendatasets) (8.1.6)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2023.7.22)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.27.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (1.26.16)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (6.0.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.4)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22
# ERROR: unknown command "pandas"

# %%
import opendatasets as od
import pandas

od.download("https://www.kaggle.com/datasets/mohamedhanyyy/chest-ctscan-images")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: nithishkumar0227
# Your Kaggle Key: ··········
# Downloading chest-ctscan-images.zip to ./chest-ctscan-images
# 100%|██████████| 119M/119M [00:01<00:00, 119MB/s]

# %%
import os
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
# File Directory for both the train and test
train_path = "/content/chest-ctscan-images/Data/train"
val_path = "/content/chest-ctscan-images/Data/valid"
test_path = "/content/chest-ctscan-images/Data/test"

# %%
def GetDatasetSize(path):
    num_of_image = {}
    for folder in os.listdir(path):
        # Counting the Number of Files in the Folder
        num_of_image[folder] = len(os.listdir(os.path.join(path, folder)));
    return num_of_image;

train_set = GetDatasetSize(train_path)
val_set = GetDatasetSize(val_path)
test_set = GetDatasetSize(test_path)
print(train_set,"\n\n",val_set,"\n\n",test_set)
# Out:
# {'normal': 148, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 115, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 155, 'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 195}
#
#  {'normal': 13, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 21, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 15, 'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 23}
#
#  {'squamous.cell.carcinoma': 90, 'normal': 54, 'adenocarcinoma': 120, 'large.cell.carcinoma': 51}

# %%
import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))
# Out:
# matplotlib: 3.7.1

# %%
# !pip install matplotlib --upgrade
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Collecting matplotlib
#   Downloading matplotlib-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 44.6 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Collecting pyparsing<3.1,>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, matplotlib
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.0
#     Uninstalling pyparsing-3.1.0:
#       Successfully uninstalled pyparsing-3.1.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# Successfully installed matplotlib-3.7.2 pyparsing-3.0.9

# %%
labels = ['Squamous Cell Carcinoma', 'Normal', 'Adenocarcinoma', 'Large Cell Carcinoma']
train_list = list(train_set.values())
val_list = list(val_set.values())
test_list = list(test_set.values())

x = np.arange(len(labels))  # the label locations
width = 0.20  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, train_list, width, label='Train',color = 'red')
rects2 = ax.bar(x, val_list, width, label='Val', color = 'blue')
rects3 = ax.bar(x + width, test_list, width, label='Test', color = 'green')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Images Count')
ax.set_title('Dataset')
ax.set_xticks(x)
ax.set_xticklabels(labels)
plt.xticks(rotation=15)
ax.legend()

ax.bar_label(rects1)
ax.bar_label(rects2)
ax.bar_label(rects3)

fig.tight_layout()

plt.show()

# %% [markdown]
# <h2>
# Importing Keras for Image Classification

# %%
import tensorflow.keras
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Dense,Conv2D, Flatten, MaxPool2D, Dropout

# %%
train_datagen = ImageDataGenerator(rescale = 1.0/255.0,
                                  horizontal_flip = True,
                                  fill_mode = 'nearest',
                                  zoom_range=0.2,
                                  shear_range = 0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  rotation_range=0.4)

train_data = train_datagen.flow_from_directory(train_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 613 images belonging to 4 classes.

# %%
train_data.class_indices
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
val_datagen = ImageDataGenerator(rescale = 1.0/255.0)
val_data = val_datagen.flow_from_directory(val_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 72 images belonging to 4 classes.

# %%
val_data.class_indices
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
test_datagen = ImageDataGenerator(rescale = 1.0/255.0)
test_data = test_datagen.flow_from_directory(test_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 315 images belonging to 4 classes.

# %%
test_data.class_indices
# Out:
# {'adenocarcinoma': 0,
#  'large.cell.carcinoma': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma': 3}

# %% [markdown]
# <h2>Incep

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3

base_model = InceptionV3(input_shape = (350, 350, 3),
                         include_top = False,
                         weights = 'imagenet')


for layer in base_model.layers:
    layer.trainable = False


x = layers.Flatten()(base_model.output)
x = layers.Dense(1024, activation='relu')(x)
x = layers.Dropout(0.2)(x)

# Add a final sigmoid layer with 4 node for classification output
x = layers.Dense(4, activation='sigmoid')(x)

model_incep = tf.keras.models.Model(base_model.input, x)

model_incep.compile(optimizer = tensorflow.keras.optimizers.RMSprop(learning_rate=0.0001),
                    loss = 'categorical_crossentropy',
                    metrics = ['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step

# %%
mc1 = ModelCheckpoint(
    filepath="./ct_incep_best_model.hdf5",
    monitor= 'val_accuracy',
    verbose= 1,
    save_best_only= True,
    mode = 'auto'
    );

call_back = [mc1];

# %%
# Fitting the Model
incep = model_incep.fit(
    train_data,
    steps_per_epoch = train_data.samples//train_data.batch_size,
    epochs = 32,
    validation_data = val_data,
    validation_steps = val_data.samples//val_data.batch_size,
    callbacks = call_back
    )
# Out:
# Epoch 1/32
# 122/122 [==============================] - ETA: 0s - loss: 6.6166 - accuracy: 0.4572
# Epoch 1: val_accuracy improved from -inf to 0.48571, saving model to ./ct_incep_best_model.hdf5
# 122/122 [==============================] - 54s 325ms/step - loss: 6.6166 - accuracy: 0.4572 - val_loss: 2.1934 - val_accuracy: 0.4857
# Epoch 2/32
# 122/122 [==============================] - ETA: 0s - loss: 2.1510 - accuracy: 0.5674
# Epoch 2: val_accuracy did not improve from 0.48571
# 122/122 [==============================] - 23s 186ms/step - loss: 2.1510 - accuracy: 0.5674 - val_loss: 2.3636 - val_accuracy: 0.4286
# Epoch 3/32
# 122/122 [==============================] - ETA: 0s - loss: 1.3148 - accuracy: 0.6086
# Epoch 3: val_accuracy improved from 0.48571 to 0.67143, saving model to ./ct_incep_best_model.hdf5
# 122/122 [==============================] - 29s 242ms/step - loss: 1.3148 - accuracy: 0.6086 - val_loss: 0.6475 - val_accuracy: 0.6714
# Epoch 4/32
# 122/122 [==============================] - ETA: 0s - loss: 0.9695 - accuracy: 0.6546
# Epoch 4: val_accuracy did not improve from 0.67143
# 122/122 [==============================] - 21s 170ms/step - loss: 0.9695 - accuracy: 0.6546 - val_loss: 0.9249 - val_accuracy: 0.6714
# Epoch 5/32
# 122/122 [==============================] - ETA: 0s - loss: 0.8703 - accuracy: 0.6793
# Epoch 5: val_accuracy improved from 0.67143 to 0.68571, saving model to ./ct_incep_best_model.hdf5
# 122/122 [==============================] - 41s 341ms/step - loss: 0.8703 - accuracy: 0.6793 - val_loss: 0.7959 - val_accuracy: 0.6857
# Epoch 6/32
# 122/122 [==============================] - ETA: 0s - loss: 0.8361 - accuracy: 0.7039
# Epoch 6: val_accuracy improved from 0.68571 to 0.78571, saving model to ./ct_incep_best_model.hdf5
# 122/122 [==============================] - 31s 250ms/step - loss: 0.8361 - accuracy: 0.7039 - val_loss: 0.5186 - val_accuracy: 0.7857
# Epoch 7/32
# 122/122 [==============================] - ETA: 0s - loss: 0.7497 - accuracy: 0.7336
# Epoch 7: val_accuracy did not improve from 0.78571
# 122/122 [==============================] - 22s 182ms/step - loss: 0.7497 - accuracy: 0.7336 - val_loss: 0.6361 - val_accuracy: 0.7429
# Epoch 8/32
# 122/122 [==============================] - ETA: 0s - loss: 0.7222 - accuracy: 0.7352
# Epoch 8: val_accuracy did not improve from 0.78571
# 122/122 [==============================] - 24s 193ms/step - loss: 0.7222 - accuracy: 0.7352 - val_loss: 0.9968 - val_accuracy: 0.5714
# Epoch 9/32
# 122/122 [==============================] - ETA: 0s - loss: 0.6911 - accuracy: 0.7500
# Epoch 9: val_accuracy did not improve from 0.78571
# 122/122 [==============================] - 23s 187ms/step - loss: 0.6911 - accuracy: 0.7500 - val_loss: 0.6685 - val_accuracy: 0.7429
# Epoch 10/32
# 122/122 [==============================] - ETA: 0s - loss: 0.6582 - accuracy: 0.7533
# Epoch 10: val_accuracy improved from 0.78571 to 0.81429, saving model to ./ct_incep_best_model.hdf5
# 122/122 [==============================] -
32
# 122/122 [==============================] - ETA: 0s - loss: 0.3408 - accuracy: 0.8865
# Epoch 24: val_accuracy did not improve from 0.88571
# 122/122 [==============================] - 23s 186ms/step - loss: 0.3408 - accuracy: 0.8865 - val_loss: 0.5318 - val_accuracy: 0.8000
# Epoch 25/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3992 - accuracy: 0.8651
# Epoch 25: val_accuracy did not improve from 0.88571
# 122/122 [==============================] - 22s 178ms/step - loss: 0.3992 - accuracy: 0.8651 - val_loss: 0.3609 - val_accuracy: 0.8571
# Epoch 26/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3152 - accuracy: 0.8816
# Epoch 26: val_accuracy did not improve from 0.88571
# 122/122 [==============================] - 22s 177ms/step - loss: 0.3152 - accuracy: 0.8816 - val_loss: 0.8809 - val_accuracy: 0.7286
# Epoch 27/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3324 - accuracy: 0.8964
# Epoch 27: val_accuracy did not improve from 0.88571
# 122/122 [==============================] - 23s 185ms/step - loss: 0.3324 - accuracy: 0.8964 - val_loss: 0.4877 - val_accuracy: 0.7857
# Epoch 28/32
# 122/122 [==============================] - ETA: 0s - loss: 0.2458 - accuracy: 0.9013
# Epoch 28: val_accuracy did not improve from 0.88571
# 122/122 [==============================] - 21s 172ms/step - loss: 0.2458 - accuracy: 0.9013 - val_loss: 0.8590 - val_accuracy: 0.7286
# Epoch 29/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3339 - accuracy: 0.8849
# Epoch 29: val_accuracy did not improve from 0.88571
# 122/122 [==============================] - 23s 187ms/step - loss: 0.3339 - accuracy: 0.8849 - val_loss: 0.3547 - val_accuracy: 0.8857
# Epoch 30/32
# 122/122 [==============================] - ETA: 0s - loss: 0.4128 - accuracy: 0.8701
# Epoch 30: val_accuracy did not improve from 0.88571
# 122/122 [==============================] - 22s 181ms/step - loss: 0.4128 - accuracy: 0.8701 - val_loss: 0.5766 - val_accuracy: 0.8429
# Epoch 31/32
# 122/122 [==============================] - ETA: 0s - loss: 0.2767 - accuracy: 0.9095
# Epoch 31: val_accuracy did not improve from 0.88571
# 122/122 [==============================] - 21s 173ms/step - loss: 0.2767 - accuracy: 0.9095 - val_loss: 0.8142 - val_accuracy: 0.7143
# Epoch 32/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3495 - accuracy: 0.8931
# Epoch 32: val_accuracy did not improve from 0.88571
# 122/122 [==============================] - 22s 180ms/step - loss: 0.3495 - accuracy: 0.8931 - val_loss: 0.4135 - val_accuracy: 0.8714

# %%
# Loading the Best Fit Model
model_incep = load_model("./ct_incep_best_model.hdf5")

# %% [markdown]
# Resnet 50 Model

# %%
from tensorflow.keras.applications import ResNet50

base_model = ResNet50(input_shape=(350, 350,3),
                      include_top=False, weights="imagenet",
                      pooling='max')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
model_resnet = Sequential()
model_resnet.add(base_model)
model_resnet.add(Dense(4, activation='sigmoid'))

# %%
model_resnet.compile(optimizer = tf.keras.optimizers.SGD(learning_rate=0.0001),
                     loss = 'categorical_crossentropy',
                     metrics = ['accuracy'])

# %%
# Adding Model check point Callback

mc = ModelCheckpoint(
    filepath="./ct_resnet_best_model.hdf5",
    monitor= 'val_accuracy',
    verbose= 1,
    save_best_only= True,
    mode = 'auto'
    );

call_back = [mc];

# %%
# Fitting the Model
resnet = model_resnet.fit(
    train_data,
    steps_per_epoch = train_data.samples//train_data.batch_size,
    epochs = 32,
    validation_data = val_data,
    validation_steps = val_data.samples//val_data.batch_size,
    callbacks = call_back
    )
# Out:
# Epoch 1/32
# 122/122 [==============================] - ETA: 0s - loss: 1.7645 - accuracy: 0.2188
# Epoch 1: val_accuracy improved from -inf to 0.18571, saving model to ./ct_resnet_best_model.hdf5
# 122/122 [==============================] - 29s 195ms/step - loss: 1.7645 - accuracy: 0.2188 - val_loss: 1.5228 - val_accuracy: 0.1857
# Epoch 2/32
# 122/122 [==============================] - ETA: 0s - loss: 1.3732 - accuracy: 0.3322
# Epoch 2: val_accuracy improved from 0.18571 to 0.44286, saving model to ./ct_resnet_best_model.hdf5
# 122/122 [==============================] - 22s 183ms/step - loss: 1.3732 - accuracy: 0.3322 - val_loss: 1.2275 - val_accuracy: 0.4429
# Epoch 3/32
# 122/122 [==============================] - ETA: 0s - loss: 1.2669 - accuracy: 0.3882
# Epoch 3: val_accuracy improved from 0.44286 to 0.45714, saving model to ./ct_resnet_best_model.hdf5
# 122/122 [==============================] - 23s 189ms/step - loss: 1.2669 - accuracy: 0.3882 - val_loss: 1.2021 - val_accuracy: 0.4571
# Epoch 4/32
# 122/122 [==============================] - ETA: 0s - loss: 1.2140 - accuracy: 0.4227
# Epoch 4: val_accuracy improved from 0.45714 to 0.48571, saving model to ./ct_resnet_best_model.hdf5
# 122/122 [==============================] - 23s 189ms/step - loss: 1.2140 - accuracy: 0.4227 - val_loss: 1.1806 - val_accuracy: 0.4857
# Epoch 5/32
# 122/122 [==============================] - ETA: 0s - loss: 1.1681 - accuracy: 0.4197
# Epoch 5: val_accuracy improved from 0.48571 to 0.50000, saving model to ./ct_resnet_best_model.hdf5
# 122/122 [==============================] - 22s 181ms/step - loss: 1.1681 - accuracy: 0.4197 - val_loss: 1.1441 - val_accuracy: 0.5000
# Epoch 6/32
# 122/122 [==============================] - ETA: 0s - loss: 1.1303 - accuracy: 0.4770
# Epoch 6: val_accuracy did not improve from 0.50000
# 122/122 [==============================] - 22s 183ms/step - loss: 1.1303 - accuracy: 0.4770 - val_loss: 1.0906 - val_accuracy: 0.4286
# Epoch 7/32
# 122/122 [==============================] - ETA: 0s - loss: 1.1220 - accuracy: 0.4605
# Epoch 7: val_accuracy did not improve from 0.50000
# 122/122 [==============================] - 22s 180ms/step - loss: 1.1220 - accuracy: 0.4605 - val_loss: 1.0819 - val_accuracy: 0.4714
# Epoch 8/32
# 122/122 [==============================] - ETA: 0s - loss: 1.1224 - accuracy: 0.4589
# Epoch 8: val_accuracy did not improve from 0.50000
# 122/122 [==============================] - 21s 176ms/step - loss: 1.1224 - accuracy: 0.4589 - val_loss: 1.0243 - val_accuracy: 0.5000
# Epoch 9/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0975 - accuracy: 0.4622
# Epoch 9: val_accuracy improved from 0.50000 to 0.51429, saving model to ./ct_resnet_best_model.hdf5
# 122/122 [==============================] - 23s 189ms/step - loss: 1.0975 - accuracy: 0.4622 - val_loss: 1.2314 - val_accuracy: 0.5143
# Epoch 10/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0972 - accuracy: 0.4556
# Epoch 10: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 23s 186ms/step - loss: 1.0972 - accuracy: 0.4556 - val_loss: 1.0523 - val_accuracy: 0.3571
# Epoch 11/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0600 - accuracy: 0.4753
# Epoch 11: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 21s 174ms/step - loss: 1.0600 - accuracy: 0.4753 - val_loss: 1.1309 - val_accuracy: 0.4000
# Epoch 12/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0892 - accuracy: 0.4770
# Epoch 12: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 22s 183ms/step - loss: 1.0892 - accuracy: 0.4770 - val_loss: 1.0394 - val_accuracy: 0.4429
# Epoch 13/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0992 - accuracy: 0.4556
# Epoch 13: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 21s 175ms/step - loss: 1.0992 - accuracy: 0.4556 - val_loss: 1.1463 - val_accuracy: 0.3857
# Epoch 14/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0699 - accuracy: 0.4704
# Epoch 14: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 22s 183ms/step - loss: 1.0699 - accuracy: 0.4704 - val_loss: 1.0573 - val_accuracy: 0.3714
# Epoch 15/32
# 122/122 [==============================] - ETA: 0s - loss: 1.
32
# 122/122 [==============================] - ETA: 0s - loss: 1.0392 - accuracy: 0.5000
# Epoch 32: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 22s 179ms/step - loss: 1.0392 - accuracy: 0.5000 - val_loss: 0.9658 - val_accuracy: 0.4429

# %%
# Loading the Best Fit Model
model = load_model("./ct_resnet_best_model.hdf5")

# %%
test_score = model_incep.evaluate_generator(generator= test_data)
test_score_resnet = model.evaluate_generator(generator= test_data)

# %%
# Checking the Accuracy of the Model Resnet50
accuracy_resnet = model.evaluate_generator(generator= test_data)[1]
print(f"The accuracy of the model is = {accuracy_resnet*100} %")
loss_resnet = test_score[0]
print(f"The loss of the model is = {loss_resnet} %")
# Out:
# The accuracy of the model is = 53.33333611488342 %
# The loss of the model is = 0.5917348861694336 %

# %%
# Checking the Accuracy of the Incep
accuracy_incep = model_incep.evaluate_generator(generator= test_data)[1]
print(f"The accuracy of the model is = {accuracy_incep*100} %")
loss_incep = test_score[0]
print(f"The loss of the model is = {loss_incep} %")
# Out:
# The accuracy of the model is = 80.95238208770752 %
# The loss of the model is = 0.5917348861694336 %

# %%
incep.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Plot model performance
acc = incep.history['accuracy']
val_acc = incep.history['val_accuracy']
loss = incep.history['loss']
val_loss = incep.history['val_loss']
epochs_range = range(1, len(incep.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()

# %%
algos = ['Resnet50','Incep']
accuracy = [accuracy_resnet, accuracy_incep]
accuracy = np.floor([i * 100 for i in accuracy])

fig = plt.figure(figsize = (2, 5))
#fig.set_figwidth(4)

# creating the bar plot
plt.bar(algos, accuracy, color ='blue', width = 0.1)

plt.xlabel("Algorithms Applied")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# Confusion Matrix

# %%
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(20,20))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
        thresh = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, cm[i, j],
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
            plt.tight_layout()
            plt.ylabel('True label')
            plt.xlabel('Predicted label')
#Print the Target names
from sklearn.metrics import classification_report, confusion_matrix
import itertools
#shuffle=False
target_names = []
for key in train_data.class_indices:
    target_names.append(key)
# print(target_names)
#Confution Matrix
Y_pred = model.predict_generator(test_data)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
cm = confusion_matrix(test_data.classes, y_pred)
plot_confusion_matrix(cm, target_names, title='Confusion Matrix')
#Print Classification Report
print('Classification Report')
print(classification_report(test_data.classes, y_pred, target_names=target_names))
# Out:
# Confusion Matrix
# Normalized confusion matrix
# Classification Report
#                                                   precision    recall  f1-score   support
#
#       adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib       0.40      0.83      0.54       120
#    large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa       0.00      0.00      0.00        51
#                                           normal       0.17      0.20      0.18        54
# squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa       0.00      0.00      0.00        90
#
#                                         accuracy                           0.35       315
#                                        macro avg       0.14      0.26      0.18       315
#                                     weighted avg       0.18      0.35      0.24       315

# %% [markdown]
# Predictions

# %%
def chestScanPrediction(path, _model):
    classes_dir = ["Adenocarcinoma","Large cell carcinoma","Normal","Squamous cell carcinoma"]
    # Loading Image
    img = image.load_img(path, target_size=(350,350))
    # Normalizing Image
    norm_img = image.img_to_array(img)/250
    # Converting Image to Numpy Array
    input_arr_img = np.array([norm_img])
    # Getting Predictions
    pred = np.argmax(_model.predict(input_arr_img))
    # Printing Model Prediction
    print(classes_dir[pred])

# %%
path = "/content/chest-ctscan-images/Data/test/adenocarcinoma/000108 (3).png"
chestScanPrediction(path,model_incep)
# Out:
# 1/1 [==============================] - 3s 3s/step
# Squamous cell carcinoma
